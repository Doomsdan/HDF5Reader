# %%
import lauchaecker_hdf5_tools as lht
import meteox2y as mxy

# %pylab inline
# Out:
# P:\wetterstation\04_Data
# Populating the interactive namespace from numpy and matplotlib

# %%
lht.hdf5_2_soilplot(start='2024-01-01T00:00:00',del_t=60, end='2024-07-20T00:00:00')

# %%
lht.hdf5_2_pluviogram(start='2025-05-22T00:00:00',del_t=60, end='2025-05-26T00:00:00')#, hdf5=r'p:\wetterstation\04_Data\lauchaecker.h5')
# Out:
# Summe (nansum)  Thies F 3.6000000536441803
# Summe (nansum)  Seba G 0.0
# Summe (nansum)  Thies N 3.200000062584877
# Summe (nansum)  Seba T 3.0049999160692096
# Summe (nansum)  Ott Pluvio W 3.0899999253451824
# Summe (nansum)  SBS1000_Tot 3.4000000655651093
# Summe (nansum)  Pluvio2_Avg 195.51000041514635

# %%
lht.plot_data(start='2021-12-01T00:00:00',del_t=5, end='2022-01-01T00:00:00',varpath=['rr_10'])

# %%
lht.plot_data(start='2020-01-01T00:00:00',del_t=1440, end='2024-07-20T00:00:00',varpath=['VWC_01','VWC_02','VWC_03','VWC_04','VWC_05','rr_07'])

# %%
lht.evapo_plot(start='2021-08-01T00:00:00', end='2021-10-01T00:00:00')

# %%
lht.compare_year(2023, hdf5=r'P:\wetterstation\04_Data\lauchaecker.h5',
                 long_data=r'p:\wetterstation\04_Data\Stuttgart-Echterdingen_temp_61_90.txt' )

# %%
lht.hdf52txt(start='2018-11-01T00:00:00', end='2019-04-01T00:00:00',varpath=['G', 'RK','E','A'],outfile='Strahlung_Lauchaecker.txt', del_t=1)

# %%
lht.hdf52txt(start='2018-04-01T00:00:00', end='2018-11-01T00:00:00',
             varpath=['rr_07', 'rr_10'],
             outfile='Pluvios_Apr18_Nov18.txt', 
             del_t=60)

# %%
lht.hdf52txt(start='2015-01-01T00:00:00', end='2016-01-01T00:00:00',varpath=['Ta_18m'],outfile='Ta_18.txt', del_t=60)

# %%
# Anfrage Meinolf Koßmann
lht.hdf52txt(start='2017-01-01T00:00:00', end='2019-01-01T00:00:00',varpath=['p','rr_10','u_19m','dd_19m','dd_2m','u_2m','Ta_2m','rh_2m','Ta_18m','rh_18m','G','RK','E','A'],outfile='DWD_Kossmann.txt', del_t=1)

# %%
# Bachelorarbeit Jessica Sienel
#lht.hdf52txt(start='2014-10-15T00:00:00', end='2019-01-05T00:00:00',varpath=['rr_03','rr_05','rr_06','rr_07','rr_04','rr_09','rr_10','dd_2m','u_2m','Ta_2m','dd_2m_sigma'],outfile='Daten_Jessica.txt', del_t=1)
lht.hdf52txt(start='2019-01-05T00:00:00', end='2019-06-24T00:00:00',varpath=['rr_03','rr_05','rr_06','rr_07','rr_04','rr_09','rr_10','dd_2m','u_2m','Ta_2m','dd_2m_sigma'],outfile='Daten_Jessica_update.txt', del_t=1)

# %%
# Stahlungsdaten Leonie Nietfeld
lht.hdf52txt(start='2019-10-01T00:00:00', end='2020-04-01T10:00:00',varpath=['G','RK','E','A'],outfile='Strahlungsdaten_2020-04-01.txt', del_t=1)

# %%
# Daten für Claus
lht.hdf52txt(start='2014-01-01T00:00:00', end='2020-04-01T10:00:00',varpath=['G','RK','E','A','Ta_2m','Tg_2cm','Tg_5cm','Tg_10cm','Tg_20cm','Tg_50cm','VWC_01','VWC_02','VWC_03','VWC_04','VWC_05'],outfile='Claus.txt', del_t=60)

# %%
# Niederschlag für Claus
lht.hdf52txt(start='2014-01-01T00:00:00', end='2020-04-01T10:00:00',varpath=['rr_10'],outfile='Claus_PCP.txt', del_t=60)

# %%
# Wind / Feuchte für Claus
lht.hdf52txt(start='2014-01-01T00:00:00', end='2020-04-01T10:00:00',varpath=['rh_2m','u_2m','dd_2m' ],outfile='Claus_u_rf.txt', del_t=60)

# %%
# Wind oben und Luftdruck
lht.hdf52txt(start='2014-01-01T00:00:00', end='2020-04-01T10:00:00',varpath=['p','u_19m','dd_19m' ],outfile='hupsi2.txt', del_t=60)

# %%
# Pluvio für NetAtmo Vergleich
lht.hdf52txt(start='2019-01-01T00:00:00', end='2020-04-01T10:00:00',varpath=['rr_07','rr_09','rr_10'],outfile='pcp_lauchaecker_1min.txt', del_t=1)

# %%
#Wind Maria Scheuerlein
lht.hdf52txt(start='2019-05-19T00:00:00', end='2019-05-20T00:00:00',varpath=['dd_2m','u_2m',],outfile='Wind20190519.txt', del_t=1)
lht.hdf52txt(start='2019-05-21T00:00:00', end='2019-05-22T00:00:00',varpath=['dd_2m','u_2m',],outfile='Wind20190521.txt', del_t=1)
lht.hdf52txt(start='2019-05-25T00:00:00', end='2019-05-26T00:00:00',varpath=['dd_2m','u_2m',],outfile='Wind20190525.txt', del_t=1)

# %%
#Anfrage Kerekes IIGS
lht.hdf52txt(start='2018-12-01T00:00:00', end='2019-12-01T00:00:00',varpath=['Ta_2m','rh_2m','p'],outfile='Daten_IIGS.txt', del_t=1)

# %%
#Anfrage Karim Radhouani
lht.hdf52txt(start='2018-01-01T00:00:00', end='2019-01-01T00:00:00',varpath=['G','Ta_2m','rh_2m', 'dd_19m', 'u_19m'],outfile='Daten_Karim_Radhouani.txt', del_t=1)

# %%
#Anfrage Jonas Romblad IAG
lht.hdf52txt(start='2020-03-07T10:00:00', end='2020-03-07T19:00:00',varpath=['G','Ta_2m','dd_2m','u_2m', 'dd_19m', 'u_19m','p'],outfile='Daten_Jonad-Romblad.txt', del_t=1)

# %%
#2. Anfrage Jonas Romblad IAG
lht.hdf52txt(start='2019-10-03T00:00:00', end='2020-10-13T00:00:00',varpath=['G','Ta_2m','dd_2m','u_2m', 'dd_19m', 'u_19m','p', 'rh_2m','rr_10'],outfile='Daten_Jonad-Romblad2.txt', del_t=1)

# %%
#Anfrage Janina Buhl (Daimler bzw. ISWA)
lht.hdf52txt(start='2018-01-01T00:00:00', end='2020-01-01T00:00:00',varpath=['rr_10'],outfile='pcp_lauchaecker_1h_2018_2019.txt', del_t=1)

# %%
# Niederschlag für Claus
lht.hdf52txt(start='2014-01-01T00:00:00', end='2020-04-01T10:00:00',varpath=['rr_10'],outfile='Claus_PCP.txt', del_t=60)

# %%
# Daten Adrian Eitle 2020-09-01
lht.hdf52txt(start='2020-08-07T00:00:00', end='2020-08-22T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m'],outfile='Daten_Adrian_Eitle.txt', del_t=1)

# %%
# Daten für Claus April-Mitte September
lht.hdf52txt(start='2020-04-01T10:00:00', end='2020-09-10T10:00:00',varpath=['A','E','G','RK','Ta_2m','Tg_10cm','Tg_20cm','Tg_2cm','Tg_50cm','Tg_5cm','VWC_01','VWC_02','VWC_03','VWC_04','VWC_05','dd_19m','p','u_19m','rr_10','Qg'
],outfile='Claus_Apr_Sep.txt', del_t=60)

# %%
# Daten für Claus April-Mitte September
lht.hdf52txt(start='2020-04-01T10:00:00', end='2020-09-10T10:00:00',varpath=['rh_2m','u_2m'],outfile='Claus_Apr_Sep_Nachschlag.txt', del_t=60)

# %%
#Daten für Nils Bayer (IGTE)
lht.hdf52txt(start='2017-01-01T00:00:00', end='2020-09-10T00:00:00',varpath=['Ta_2m','rh_2m','p'],outfile='Daten_IGTE.txt', del_t=5)

# %%
#Daten für Lucas Zerweck (IBP)
lht.hdf52txt(start='2018-01-01T00:00:00', end='2020-01-01T00:00:00',varpath=['Ta_2m','G','u_19m'],outfile='Daten_IBP.txt', del_t=1)

# %%
# Daten für Claus September - Ende 2020
lht.hdf52txt(start='2020-09-10T10:00:00', end='2020-12-11T00:00:00',
             varpath=['A','E','G','RK','Ta_2m','Tg_10cm','Tg_20cm','Tg_2cm','Tg_50cm','Tg_5cm','VWC_01','VWC_02','VWC_03','VWC_04','VWC_05','dd_19m','p','u_19m','rr_10','Qg', 'rh_2m','u_2m'],
             outfile='Claus_Apr_Sep_Nachschlag.txt', del_t=60)

# %%
#Daten für Laura Manoliu
#lht.hdf52txt(start='2021-01-29T00:00:00', end='2021-01-30T00:00:00',varpath=['Ta_2m','rh_2m','p','G','RK','rr_10'],outfile='Daten_20202129_DLR.txt', del_t=1)
# taglich Jan-Mär
lht.hdf52txt(start='2021-01-15T00:00:00', end='2021-03-31T00:00:00',varpath=['Ta_2m','rh_2m','p','rr_10'],outfile='Daten_täglich_DLR.txt', del_t=1)

# %%
#Daten für Dhiraj
lht.hdf52txt(start='2018-03-01T00:00:00', end='2021-03-10T00:00:00',varpath=['Ta_2m','rr_10'],outfile='Data_Dhiraj.txt', del_t=1)

# %%
#Daten für md Test
lht.hdf52txt(start='2020-03-01T00:00:00', end='2020-05-10T00:00:00',varpath=['rr_10'],outfile='md_test.txt', del_t=5)

# %%
# Daten Pia Krause (Adrian) Eitle 2021-03-26
lht.hdf52txt(start='2021-02-08T00:00:00', end='2021-02-25T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m'],outfile='Daten_Pia_Krause.txt', del_t=1)

# %%
# Daten für Kübra Yaldiz
lht.hdf52txt(start='2021-03-30T00:00:00', end='2021-04-08T00:00:00',varpath=['Ta_2m','p','rh_2m'],outfile='Daten_KYaldiz.txt', del_t=1)

# %%
# Daten für Linda Meier
lht.hdf52txt(start='2021-02-15T00:00:00', end='2021-05-31T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier.txt', del_t=1)

# %%
# Daten für Lukas Dufner (ISWA) 17.06.2021
lht.hdf52txt(start='2021-06-14T00:00:00', end='2021-06-15T00:00:00',varpath=['G'],outfile='Daten_LukasDufner2.txt', del_t=1)

# %%
# Daten für Linda Meier Juni/Juli 2021
lht.hdf52txt(start='2021-06-01T00:00:00', end='2021-08-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2.txt', del_t=1)

# %%
# Daten für Christina Eisenbarth ILEK
lht.hdf52txt(start='2010-01-01T00:00:00', end='2020-09-01T00:00:00',varpath=['dd_19m', 'u_19m', 'rr_07','rr_10','Ta_2m','rh_2m'],outfile='Daten_ChristinaILEK.txt', del_t=60)

# %%
# Daten für Mark Förster
lht.hdf52txt(start='2009-09-01T00:00:00', end='2021-09-01T00:00:00',varpath=[ 'Ta_2m'],outfile='Daten_MarkFörster.txt', del_t=60)

# %%
# Daten für Walter Haase ILEK
lht.hdf52txt(start='2010-01-01T00:00:00', end='2020-09-01T00:00:00',varpath=['dd_19m', 'u_19m', 'dd_2m','u_2m','Ta_2m','rh_2m'],outfile='WinddatenILEK.txt', del_t=60)

# %%
# Daten für Kübra Yaldiz Teil 2
lht.hdf52txt(start='2021-05-01T00:00:00', end='2021-06-16T00:00:00',varpath=['Ta_2m','p','rh_2m','rr_07'],outfile='Daten_KYaldiz2.txt', del_t=1)
lht.hdf52txt(start='2021-09-01T00:00:00', end='2021-09-16T00:00:00',varpath=['Ta_2m','p','rh_2m','rr_07'],outfile='Daten_KYaldiz3.txt', del_t=1)

# %%
# 2. Daten für Linda Meier
lht.hdf52txt(start='2021-05-31T00:00:00', end='2021-06-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier20210531.txt', del_t=1)
lht.hdf52txt(start='2021-08-01T00:00:00', end='2021-10-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2021AugSep.txt', del_t=1)

# %%
#2. Datenlieferung für Nils Bayer (IGTE)
lht.hdf52txt(start='2020-01-01T00:00:00', end='2021-01-01T00:00:00',varpath=['Ta_2m','rh_2m','p'],outfile='Daten_IGTE2.txt', del_t=5)

# %%
# 3. Daten für Linda Meier
lht.hdf52txt(start='2021-10-01T00:00:00', end='2021-12-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2021OktNov.txt', del_t=1)
#lht.hdf52txt(start='2021-08-01T00:00:00', end='2021-10-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2021AugSep.txt', del_t=1)

# %%
# Daten für Walter Haase ILEK
lht.hdf52txt(start='2010-01-01T00:00:00', end='2020-09-01T00:00:00',varpath=['dd_19m', 'u_19m', 'dd_2m','u_2m','Ta_2m','rh_2m'],outfile='WinddatenILEK.txt', del_t=60)

# %%
# Daten für Walter Haase ILEK update
#lht.hdf52txt(start='2020-09-01T00:00:00', end='2022-01-01T00:00:00',varpath=['dd_19m', 'u_19m', 'dd_2m','u_2m','Ta_2m','rh_2m'],outfile='WinddatenILEK_update.txt', del_t=60)
lht.hdf52txt(start='2020-09-01T00:00:00', end='2022-01-01T00:00:00',varpath=['rr_10', 'rr_07'],outfile='WinddatenILEK_update_pcp.txt', del_t=60)

# %%
# Daten für Jessica Hemmerling 
lht.hdf52txt(start='2021-04-01T00:00:00', end='2021-12-01T00:00:00',varpath=['p'],outfile='Daten_JessicaHemmerling.txt', del_t=1)

# %%
# Daten für Simon Koenigsdorff StZ
lht.hdf52txt(start='2021-06-28T12:00:00',del_t=1, end='2021-06-30T00:00:00',varpath=['rr_10'],outfile='pcp_juni2021.txt')
lht.hdf52txt(start='2021-06-28T12:00:00',del_t=10, end='2021-06-30T00:00:00',varpath=['rr_10'],outfile='pcp10_juni2021.txt')

# %%
# Daten Pia Krause (Adrian Eitle) 2022-03-07
lht.hdf52txt(start='2021-02-27T00:00:00', end='2021-03-07T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m'],outfile='Daten_Pia_Krause.txt', del_t=1)

# %%
lht.hdf52txt(start='2019-01-01T00:00:00', end='2020-01-01T00:00:00',varpath=['rh_2m'],outfile='rh_2019.txt', del_t=1440)

# %%
#Daten für Nils Bayer (IGTE)
lht.hdf52txt(start='2020-09-10T00:00:00', end='2022-01-01T00:00:00',varpath=['Ta_2m','rh_2m','p'],outfile='Daten_IGTE2.txt', del_t=5)

# %%
#Daten für Amar
lht.hdf52txt(start='2015-01-01T00:00:00', end='2022-04-16T00:00:00',varpath=['rr_10','Ta_2m'],outfile='DatenAmar.txt', del_t=1440)

# %%
#Daten für Stella (19.05.2022)
lht.hdf52txt(start='2009-01-01T00:00:00', end='2022-04-16T00:00:00',varpath=['Ta_2m'],outfile='DatenStella.txt', del_t=1)

# %%
#Daten für Lukas Duffner (23.05.2022)
lht.hdf52txt(start='2022-05-09T00:00:00', end='2022-05-10T00:00:00',varpath=['G'],outfile='G_20220509.txt', del_t=1)
lht.hdf52txt(start='2022-05-18T00:00:00', end='2022-05-19T00:00:00',varpath=['G'],outfile='G_20220518.txt', del_t=1)

# %%
#Daten für Amar
lht.hdf52txt(start='2018-01-01T00:00:00', end='2022-05-01T00:00:00',varpath=['rr_10'],outfile='pcplauch1h.txt', del_t=60)

# %%
#Daten für Muammar Alrais (IEH)
lht.hdf52txt(start='2022-05-21T00:00:00', end='2022-06-06T00:00:00',varpath=['G','Ta_2m'],outfile='Daten_IEH.txt', del_t=1)

# %%
#Daten für Lukas Duffner (12.07.2022)
#lht.hdf52txt(start='2022-05-25T00:00:00', end='2022-05-26T00:00:00',varpath=['G'],outfile='G_20220525.txt', del_t=1)
#lht.hdf52txt(start='2022-05-30T00:00:00', end='2022-06-01T00:00:00',varpath=['G'],outfile='G_20220530.txt', del_t=1)
#lht.hdf52txt(start='2022-06-30T00:00:00', end='2022-07-01T00:00:00',varpath=['G'],outfile='G_20220630.txt', del_t=1)
lht.hdf52txt(start='2022-07-05T00:00:00', end='2022-07-07T00:00:00',varpath=['G'],outfile='G_20220705.txt', del_t=1)

# %%
# 3. Daten für Linda Meier
lht.hdf52txt(start='2022-05-01T00:00:00', end='2022-07-27T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier20210531.txt', del_t=1)
#lht.hdf52txt(start='2021-08-01T00:00:00', end='2021-10-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2021AugSep.txt', del_t=1)

# %%
lht.hdf52txt(start='2018-06-01T00:00:00', end='2022-07-01T00:00:00',varpath=['rr_03','rr_05','rr_06','rr_07','rr_04','rr_09','rr_10'],outfile='Daten_Faizan.txt', del_t=1)

# %%
lht.hdf52txt(start='2022-07-01T00:00:00', end='2022-07-15T00:00:00',varpath=['Ta_2m', 'Ta_18m'],outfile='Temperaturgehampel.txt', del_t=1)

# %%
# 4. Daten für Linda Meier
lht.hdf52txt(start='2022-07-26T00:00:00', end='2022-09-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2022JuliAugust.txt', del_t=1)
#lht.hdf52txt(start='2021-08-01T00:00:00', end='2021-10-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2021AugSep.txt', del_t=1)

# %%
#Daten für Lukas Duffner (08.11.2022)
lht.hdf52txt(start='2022-05-25T00:00:00', end='2022-06-01T00:00:00',varpath=['G'],outfile='G_2022_Mai.txt', del_t=1)
lht.hdf52txt(start='2022-07-05T00:00:00', end='2022-07-16T00:00:00',varpath=['G'],outfile='G_2022_Juli.txt', del_t=1)
lht.hdf52txt(start='2022-08-16T00:00:00', end='2022-08-31T00:00:00',varpath=['G'],outfile='G_2022_August.txt', del_t=1)
lht.hdf52txt(start='2022-09-01T00:00:00', end='2022-09-23T00:00:00',varpath=['G'],outfile='G_2022_September.txt', del_t=1)

# %%
# Daten für Walter Haase ILEK update 2
lht.hdf52txt(start='2022-09-01T00:00:00', end='2022-11-01T00:00:00',varpath=['dd_19m', 'u_19m', 'Ta_2m','rh_2m', 'rr_10'],outfile='ILEK_update2022SepOkt.txt', del_t=1)
#lht.hdf52txt(start='2022-09-01T00:00:00', end='2022-01-01T00:00:00',varpath=['rr_10', 'rr_07'],outfile='WinddatenILEK_update_pcp.txt', del_t=60)

# %%
# Daten für Fatima Mata Marquez Institut für Thermodynamik DLR
lht.hdf52txt(start='2023-02-09T00:00:00', end='2023-02-11T00:00:00',varpath=['p'],outfile='DruckdatenFeb.txt', del_t=1)

# %%
# Daten für Claus 2021 und 2022
lht.hdf52txt(start='2021-01-01T00:00:00', end='2022-12-31T00:00:00',
             varpath=['A','E','G','RK','Ta_2m','Tg_10cm','Tg_20cm','Tg_2cm','Tg_50cm','Tg_5cm','VWC_01','VWC_02','VWC_03','VWC_04','VWC_05','dd_19m','p','u_19m','rr_10','Qg', 'rh_2m','u_2m'],
             outfile='Claus_2021_2022.txt', del_t=60)

# %%
# Daten Holger Röseler, IABP (über Pia Kraus) 2023-05-15
lht.hdf52txt(start='2023-03-01T00:00:00', end='2023-04-01T00:00:00',varpath=['G','Ta_2m','u_19m','dd_19m','rh_2m', 'rr_07'],outfile='Daten_HolgerRoeseler1.txt', del_t=1)
lht.hdf52txt(start='2023-05-01T00:00:00', end='2023-05-06T00:00:00',varpath=['G','Ta_2m','u_19m','dd_19m','rh_2m', 'rr_07'],outfile='Daten_HolgerRoeseler2.txt', del_t=1)

# %%
# Daten Stefan Weingand, IABP (über Pia Kraus) 2023-05-15
lht.hdf52txt(start='2023-03-22T00:00:00', end='2023-03-23T00:00:00',varpath=['G'],outfile='Daten_StefanWeingand.txt', del_t=1)

# %%
# Daten für Claus/Judith 2020
lht.hdf52txt(start='2020-01-01T00:00:00', end='2021-01-01T00:00:00',
             varpath=['A','E','G','RK','Ta_2m','Tg_10cm','Tg_20cm','Tg_2cm','Tg_50cm','Tg_5cm','VWC_01','VWC_02','VWC_03','VWC_04','VWC_05','dd_19m','p','u_19m','rr_10','Qg', 'rh_2m','u_2m'],
             outfile='Claus_2020.txt', del_t=60)

# %%
#Daten für Sarah Heilemann (14.06.2023) Projektarbeit Masterstudium
lht.hdf52txt(start='2010-01-01T00:00:00', end='2023-05-01T00:00:00',
             varpath=['G','Ta_2m','dd_19m','u_19m','rh_2m'],
             outfile='DatenSarahHeilemann.txt', del_t=1440)

# %%
#Daten für Stefan Kazmaier (01.08.2023) IHFG, Masterarbeit
lht.hdf52txt(start='2023-07-21T00:00:00', end='2023-07-26T00:00:00',
             varpath=['A','E','G','RK','Ta_2m','p','rh_2m'],
             outfile='DatenStefanKazmeier.txt', del_t=1)

# %%
#Daten für Simon Schneider (06.08.2023) ILEK, Daten für ausgefallenen Pluvio
lht.hdf52txt(start='2022-09-08T00:00:00', end='2022-11-25T00:00:00',
             varpath=['rr_10'],
             outfile='DatenSimonSchneider1.txt', del_t=1)

lht.hdf52txt(start='2023-03-02T00:00:00', end='2023-04-15T00:00:00',
             varpath=['rr_10'],
             outfile='DatenSimonSchneider2.txt', del_t=1)

# %%
#Daten für Felix Dick (01.08.2023) ILPOE, Bachelorarbeit (Hans-Georg Schwarz von Raumer)
lht.hdf52txt(start='2011-06-01T00:00:00', end='2023-01-01T00:00:00',
             varpath=['A','E','G','RK','Ta_2m','p','rh_2m','rr_07','dd_19m','u_19m','VWC_01','VWC_02','VWC_03','VWC_04','VWC_05'],
             outfile='DatenFelixDick2011-2023.txt', del_t=1440)

# %%
#Daten für Lukas Bürkle (M.Sc.)
lht.hdf52txt(start='2019-10-01T00:00:00', end='2023-05-01T00:00:00',
             varpath=['G','RK','Ta_2m','rr_07'],
             outfile='StrahlungTempPCP.txt', del_t=60)

# %%
lht.hdf52txt(start='2021-01-01T00:00:00', end='2023-07-15T00:00:00',varpath=['Ta_2m'],outfile='Ta_Lauchaecker.txt', del_t=5)

# %%
# Daten für Silas Kalmbach (ILEK, 26.9.2023)
lht.hdf52txt(start='2021-12-12T00:00:00', end='2023-10-01T00:00:00',
             varpath=['A','E','G','RK','p','rh_2m','rr_07','dd_19m','u_19m'],
             outfile='DatenSilasKalmbach.txt', del_t=1)

# %%
lht.hdf52txt(start='2018-01-01T00:00:00', end='2025-11-01T00:00:00',varpath=['rr_07','rr_10'],outfile='pcp_lauchaecker.txt', del_t=1)

# %%
# Daten für Walter Haase ILEK update 2
lht.hdf52txt(start='2023-10-01T00:00:00', end='2023-11-01T00:00:00',varpath=['dd_19m', 'u_19m', 'Ta_2m','rh_2m', 'rr_10'],outfile='ILEK_update2023Okt.txt', del_t=1)
#lht.hdf52txt(start='2022-09-01T00:00:00', end='2022-01-01T00:00:00',varpath=['rr_10', 'rr_07'],outfile='WinddatenILEK_update_pcp.txt', del_t=60)

# %%
#Daten für Marc Lüling (M.Sc. IABP)
lht.hdf52txt(start='2022-01-01T00:00:00', end='2023-11-01T00:00:00',varpath=['Ta_2m'],outfile='DatenMarcLüling.txt', del_t=60)

# %%
#Daten für Nour Tamin (M.Sc. IABP)
lht.hdf52txt(start='2024-04-02T00:00:00', end='2024-04-08T00:00:00',varpath=['Ta_2m','u_19m','dd_19m','G','A'],outfile='DatenNourTamin.txt', del_t=1)

# %%
#Daten für Max Graf (Uni Augsburg)
lht.hdf52txt(start='2016-01-01T00:00:00', end='2024-01-01T00:00:00',varpath=['rr_07','rr_10'],outfile='DatenMax.txt', del_t=1)

# %%
#Daten für Nicholas Illich (B.Sc. Arbeit IWS)
lht.hdf52txt(start='2020-01-01T00:00:00', end='2024-04-23T00:00:00',varpath=['rr_07','rr_10','rr_09'],outfile='Lauchaecker_pcp.txt', del_t=1)

# %%
#Daten für Lukas Duffner (10.09.2024)
lht.hdf52txt(start='2024-07-25T00:00:00', end='2024-07-26T00:00:00',varpath=['G'],outfile='G_2024_25Juli.txt', del_t=1)
lht.hdf52txt(start='2024-08-09T00:00:00', end='2024-08-10T00:00:00',varpath=['G'],outfile='G_2024_8Aug.txt', del_t=1)
lht.hdf52txt(start='2024-08-28T00:00:00', end='2024-08-30T00:00:00',varpath=['G'],outfile='G_2024_28_29Aug.txt', del_t=1)
lht.hdf52txt(start='2024-09-03T00:00:00', end='2024-09-04T00:00:00',varpath=['G'],outfile='G_2024_3Sep.txt', del_t=1)

# %%
# Daten Moritz Weckmann, IABP  2024-09-29
lht.hdf52txt(start='2022-06-01T00:00:00', end='2024-09-01T00:00:00',varpath=['A','E','G','RK','Ta_2m','p','rh_2m','rr_10','dd_19m','u_19m', 'Ta_18m', 'rh_18m','u_2m', 'dd_2m'],outfile='Daten_MoritzWeckmann.txt', del_t=1)

# %%
# Daten Martino, Bryan <st189227@stud.uni-stuttgart.de> (ITKE, 3.10.2024)
lht.hdf52txt(start='2024-09-01T00:00:00', end='2024-10-02T00:00:00',varpath=['G'],outfile='Daten_BryanMartino.txt', del_t=1)

# %%
#Daten für Yesim Bakal (st151767@stud.uni-stuttgart.de) MSc Arbeit EnviMet (IABP)
lht.hdf52txt(start='2024-11-27T00:00:00', end='2024-11-28T00:00:00',varpath=['G','Ta_2m','rh_2m','dd_19m','u_19m'],outfile='YesimBakal1.txt', del_t=1)
lht.hdf52txt(start='2024-12-18T00:00:00', end='2024-12-19T00:00:00',varpath=['G','Ta_2m','rh_2m','dd_19m','u_19m'],outfile='YesimBakal2.txt', del_t=1)

# %%
# Daten für Claus/Elisabeth 2020
lht.hdf52txt(start='2022-12-28T00:00:00', end='2024-01-01T00:00:00',
             varpath=['A','E','G','RK','Ta_2m','Tg_10cm','Tg_20cm','Tg_2cm','Tg_50cm','Tg_5cm','VWC_01','VWC_02','VWC_03','VWC_04','VWC_05','dd_19m','p','u_19m','rr_10','Qg', 'rh_2m','u_2m'],
             outfile='VEGAS_2023.txt', del_t=60)

# %%
# Datern für Abdul Azzam (IER, 17.2.25)
lht.hdf52txt(start='2019-01-01T00:00:00', end='2024-01-01T00:00:00',varpath=['G','Ta_2m'],outfile='Daten_AbdulAzzam.txt', del_t=1)

# %%
# 4. Daten für Linda Meier
#lht.hdf52txt(start='2024-12-01T00:00:00', end='2025-01-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2024Dez.txt', del_t=1)
lht.hdf52txt(start='2025-01-01T00:00:00', end='2025-02-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2025Jan.txt', del_t=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-c748f71cf514> in <module>()
#       1 # 4. Daten für Linda Meier
#       2 #lht.hdf52txt(start='2024-12-01T00:00:00', end='2025-01-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2024Dez.txt', del_t=1)
# ----> 3 lht.hdf52txt(start='2025-01-01T00:00:00', end='2025-02-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2025Jan.txt', del_t=1)
#
# p:\wetterstation\02_Python\lauchaecker_hdf5_tools.pyc in hdf52txt(start, end, varpath, outfile, hdf5, del_t, typ_)
#    1327         outfile.write('%s' % date[i])
#    1328         for va in sorted(var):
# -> 1329             outfile.write('\t%7.2f' % var[va][i])
#    1330         outfile.write('\n')
#    1331     outfile.close()
#
# ...

# %%
#Daten für Lukas Duffner (04.06.2025)
lht.hdf52txt(start='2025-05-13T00:00:00', end='2025-05-17T00:00:00',varpath=['G'],outfile='G_2025_05.txt', del_t=1)
#lht.hdf52txt(start='2022-05-18T00:00:00', end='2022-05-19T00:00:00',varpath=['G'],outfile='G_20220518.txt', del_t=1)

# %%
#Daten für Maike Schmidt (M.Sc. IABP)
lht.hdf52txt(start='2024-06-01T00:00:00', end='2025-06-01T00:00:00',
             varpath=['Ta_2m','u_19m','dd_19m','G','rh_2m','rr_10'],
             outfile='DatenMaikeSchmidt.txt', 
             del_t=60)

# %%
#Daten für Max Graf (Uni Augsburg)
lht.hdf52txt(start='2016-01-01T00:00:00', end='2024-01-01T00:00:00',varpath=['rr_07','rr_10'],outfile='DatenMax.txt', del_t=1)

# %%
#Daten für PWS Vergleich
lht.hdf52txt(start='2018-11-01T00:00:00', end='2025-06-01T00:00:00',varpath=['rr_07','rr_10','rr_09'],outfile='Lauchaecker_pcp.txt', del_t=1)

# %%
# 4. Daten für Linda Meier
#lht.hdf52txt(start='2024-12-01T00:00:00', end='2025-01-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2024Dez.txt', del_t=1)
lht.hdf52txt(start='2025-01-01T00:00:00', end='2025-02-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2025Jan.txt', del_t=1)# 4. Daten für Linda Meier
#lht.hdf52txt(start='2024-12-01T00:00:00', end='2025-01-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2024Dez.txt', del_t=1)
lht.hdf52txt(start='2025-01-01T00:00:00', end='2025-02-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2025Jan.txt', del_t=1)

# %%
# Daten) IABP für Daniela Schätzel (Linda Meier
#lht.hdf52txt(start='2024-12-01T00:00:00', end='2025-01-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2024Dez.txt', del_t=1)
lht.hdf52txt(start='2025-06-30T00:00:00', end='2025-07-07T00:00:00',
             varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],
             outfile='DatenDanielaSchätzel2025_07.txt', del_t=1)

# %%
# 2. Daten) IABP für Daniela Schätzel (Linda Meier)
#lht.hdf52txt(start='2024-12-01T00:00:00', end='2025-01-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2024Dez.txt', del_t=1)
lht.hdf52txt(start='2024-08-01T00:00:00', end='2025-11-11T00:00:00',
             varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],
             outfile='DatenDanielaSchätzel_bis11Nov2025.txt', del_t=1)
# Out:
# avrwind.py:109: RuntimeWarning: invalid value encountered in double_scalars
#   angle_rad = (angle_rad + 2 * np.pi) % (2 * np.pi)
# avrwind.py:111: RuntimeWarning: invalid value encountered in double_scalars
#   norm = (u ** 2 + v ** 2) ** .5
# avrwind.py:109: RuntimeWarning: invalid value encountered in remainder
#   angle_rad = (angle_rad + 2 * np.pi) % (2 * np.pi)

# %%
#Daten für Simon
lht.hdf52txt(start='2024-01-01T00:00:00', end='2025-01-01T00:00:00',varpath=['Ta_2m'],outfile='Daten_Simon.txt', del_t=1)

# %%
#Daten für Volker Baur (2026-01-09) Msc Arbeit
lht.hdf52txt(start='2023-03-01T00:00:00', end='2023-09-01T00:00:00',varpath=['Ta_2m','dd_19m', 'u_19m','G','rh_2m', 'rr_10'],
             outfile='Daten_VolkerBaur2023.txt', del_t=60)
lht.hdf52txt(start='2024-03-01T00:00:00', end='2024-09-01T00:00:00',varpath=['Ta_2m','dd_19m', 'u_19m','G','rh_2m', 'rr_10'],
             outfile='Daten_VolkerBaur2024.txt', del_t=60)
lht.hdf52txt(start='2025-03-01T00:00:00', end='2025-09-01T00:00:00',varpath=['Ta_2m','dd_19m', 'u_19m','G','rh_2m', 'rr_10'],
             outfile='Daten_VolkerBaur2025.txt', del_t=60)
# Out:
# avrwind.py:109: RuntimeWarning: invalid value encountered in double_scalars
#   angle_rad = (angle_rad + 2 * np.pi) % (2 * np.pi)
# avrwind.py:111: RuntimeWarning: invalid value encountered in double_scalars
#   norm = (u ** 2 + v ** 2) ** .5
# avrwind.py:109: RuntimeWarning: invalid value encountered in remainder
#   angle_rad = (angle_rad + 2 * np.pi) % (2 * np.pi)

# %%
# 3. Daten) IABP für Daniela Schätzel (Linda Meier)
#lht.hdf52txt(start='2024-12-01T00:00:00', end='2025-01-01T00:00:00',varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],outfile='Daten_LindaMeier2024Dez.txt', del_t=1)
lht.hdf52txt(start='2025-11-11T00:00:00', end='2026-02-04T14:00:00',
             varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],
             outfile='DatenDanielaSchaetzel_bis04Feb2026.txt', del_t=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-8270e5f765b5> in <module>()
#       3 lht.hdf52txt(start='2025-11-11T00:00:00', end='2026-02-04T14:00:00',
#       4              varpath=['G','RK','A','E','Ta_2m','dd_19m', 'u_19m','p','rh_2m', 'rr_10'],
# ----> 5              outfile='DatenDanielaSchaetzel_bis04Feb2026.txt', del_t=1)
#
# p:\wetterstation\02_Python\lauchaecker_hdf5_tools.pyc in hdf52txt(start, end, varpath, outfile, hdf5, del_t, typ_)
#    1327         outfile.write('%s' % date[i])
#    1328         for va in sorted(var):
# -> 1329             outfile.write('\t%7.2f' % var[va][i])
#    1330         outfile.write('\n')
#    1331     outfile.close()
#
# IndexError: index 122177 is out of bounds for axis 0 with size 122177

# %% [markdown]
# ### Messtechnik Praktikum

# %%
lht.hdf52txt(start="2024-04-01T00:00:00", end="2024-05-01T00:00:00", varpath=['Ta_2m','rh_2m','p','rr_07'], 
             outfile=r"y:\Alle\Seidel\Daten_2024\meteo_apr_24.txt",del_t=60)

# %%
# Tagesdaten für Strahlung wolken
lht.hdf52txt(start="2024-05-08T00:00:00", end="2024-05-09T00:00:00",
             varpath=['Ta_2m','rh_2m','G','A','E','RK'],
             outfile=r"y:\Alle\Seidel\Daten_2024\data2024_05_08.txt", del_t=30)

# %%
# Tagesdaten für Strahlung klar
lht.hdf52txt(start="2024-05-11T00:00:00", end="2024-05-12T00:00:00",
             varpath=['Ta_2m','rh_2m','G','A','E','RK'],
             outfile=r"y:\Alle\Seidel\Daten_2024\data2024_05_11.txt", del_t=30)

# %%
svp=mxy.sat_vap_p(32.8)

# %%
svp

# %%
vp=mxy.rel2vap_p(0.34, 32.8)

# %%
vp

# %%
mxy.haude(svp, vp, 7)

# %%
mxy.penman_monteith()

# %%
mxy.penman_monteith(np.array(4.84),np.array(0.17),np.array(6.8),np.array(0.88))
